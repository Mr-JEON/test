# %%
import torch

A = torch.tensor([1, 2, 3])
B = torch.tensor([5, 6, 7])

C = A + B
print(C)
# Out:
# tensor([ 6,  8, 10])

# %%
D = A * B
print(D)

E = A.dot(B)
print(E)
# Out:
# tensor([ 5, 12, 21])
# tensor(38)
